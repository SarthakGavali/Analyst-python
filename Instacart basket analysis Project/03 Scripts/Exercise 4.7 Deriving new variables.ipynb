# %% [markdown]
# Table of contents:
# 1) Importing Libraries
# 2) Importing 'orders_products_merged1.pkl'
# 3) performing data consistency checks
# 4) Deriving new variables 'price_range_loc', 'Busiest_day', 'Busiest_period_of_day'.
# 5) Experting the file as 'ords_prods_merge_cor1.pkl'

# %%
# Importing Pandas
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\user\OneDrive\Documents\Instacart basket analysis Career foundry'

# %%
path
# Out:
# 'C:\\Users\\user\\OneDrive\\Documents\\Instacart basket analysis Career foundry'

# %%
#Importing 'Orders_products_merged' dataframe

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'prepared Data', 'orders_products_merged1.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
# create a subset
df = ords_prods_merge[:1000000]

# %%
# Creating a price label.  Define the function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else: return 'np.nan'

# %%
#apply the function df['price_range'] = df.apply(price_label, axis=1)
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27276\67122809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low_range_product'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27276\1803078573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low_range_product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5),'price_range_loc'] = 'mid_range_products'

# %%
df.loc[df['prices'] > 15,'price_range_loc'] = 'High_range_products'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# mid_range_products    756450
# Low_range_product     243550
# Name: price_range_loc, dtype: int64

# %%
 ords_prods_merge.loc[ords_prods_merge['prices'] <= 5,'price_range_loc'] = 'Low_range_products'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5),'price_range_loc'] = 'Mid_range_products'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15,'price_range_loc'] = 'High_range_products'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid_range_products     21860860
# Low_range_products     10126321
# High_range_products      417678
# Name: price_range_loc, dtype: int64

# %%
# for loop code to execute recurrent calculations.
for x in range (30, 45):
    print("my age is %d" % (x))
# Out:
# my age is 30
# my age is 31
# my age is 32
# my age is 33
# my age is 34
# my age is 35
# my age is 36
# my age is 37
# my age is 38
# my age is 39
# my age is 40
# my age is 41
# my age is 42
# my age is 43
# my age is 44

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_time_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc'],
#       dtype='object')

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []
for value in ords_prods_merge["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest day'] = result
ords_prods_merge['busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     price_range_loc  \
# ...

# %%
#TASK 4.7 deriving New Variables

# %%
result = []
for value in ords_prods_merge["orders_day_of_week"]:
    if (value == 0) or (value == 1):
        result.append("Busiest days")
    elif (value == 4) or (value == 3):
        result.append("Slowest days")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
ords_prods_merge['busiest day'] = result
ords_prods_merge['busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     price_range_loc  \
# ...

# %%
ords_prods_merge['busiest day'].value_counts(dropna=False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest day, dtype: int64

# %% [markdown]
# #OBSERVATIONS

# %% [markdown]
# #The number of 'busiest days' and 'slowest days' has increased and the number of 'regularly busy' days has decreased.

# %%
#Identifying the busiest hours of the day
ords_prods_merge['order_time_of_day'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_time_of_day, dtype: int64

# %%
#categorizing the periods of time for 'most orders'
ords_prods_merge.loc[(ords_prods_merge['order_time_of_day'] >= 9) & (ords_prods_merge['order_time_of_day'] <= 16),'busiest_period_of_day'] = 'Most orders'

# %%
# Categorizing for 'Fewest orders'
ords_prods_merge.loc[(ords_prods_merge['order_time_of_day'] >= 0) & (ords_prods_merge['order_time_of_day'] <= 6),'busiest_period_of_day'] = 'Fewest orders'

# %%
# Categorizing for 'Average orders' part1
ords_prods_merge.loc[(ords_prods_merge['order_time_of_day'] >= 17) & (ords_prods_merge['order_time_of_day'] <= 23),'busiest_period_of_day'] = 'Average orders'

# %%
# Categorizing for 'Average orders' part2
ords_prods_merge.loc[(ords_prods_merge['order_time_of_day'] >= 7) & (ords_prods_merge['order_time_of_day'] <= 8),'busiest_period_of_day'] = 'Average orders'

# %%
#checking the headers for each column
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     price_range_loc  \
# ...

# %%
# checking the frequency of values under the labels of 'busiest_period_of_day'
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most orders       21118071
# Average orders    10399967
# Fewest orders       886821
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merge['busiest_period_of_day']
# Out:
# 0           Average orders
# 1           Average orders
# 2              Most orders
# 3           Average orders
# 4              Most orders
#                  ...
# 32404854       Most orders
# 32404855       Most orders
# 32404856    Average orders
# 32404857     Fewest orders
# 32404858       Most orders
# Name: busiest_period_of_day, Length: 32404859, dtype: object

# %%
ords_prods_merge['prices'].dtype
# Out:
# dtype('float64')

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','prepared Data', 'ords_prods_merge_cor1.pkl'))
